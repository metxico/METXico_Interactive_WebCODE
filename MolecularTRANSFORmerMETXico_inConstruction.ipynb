# %% [markdown]
# <a href="https://colab.research.google.com/github/metxico/METXico_Interactive_WebCODE/blob/main/MolecularTRANSFORmerMETXico_inConstruction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers

# %%
# !pip install rdkit-pypi
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 55.1 MB/s eta 0:00:00
# ...

# %%
from transformers import RobertaTokenizer, RobertaModel
from rdkit import Chem

# %%
tokenizer = RobertaTokenizer.from_pretrained('seyonec/ChemBERTa-zinc-base-v1')
model = RobertaModel.from_pretrained('seyonec/ChemBERTa-zinc-base-v1')
# Out:
# vocab.json:   0%|          | 0.00/9.43k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/3.21k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# pytorch_model.bin:   0%|          | 0.00/179M [00:00<?, ?B/s]

# %%
smiles_sequence = "CCO"  # Ejemplo de secuencia SMILES
tokens = tokenizer(smiles_sequence, return_tensors="pt", padding=True, truncation=True)

# %%
outputs = model(**tokens)
print(outputs)
# Out:
# BaseModelOutputWithPoolingAndCrossAttentions(last_hidden_state=tensor([[[ 0.8511,  2.1786, -0.7335,  ..., -0.2723, -1.0461,  0.6268],
#          [ 1.3393,  1.9692, -0.6810,  ...,  0.0738,  0.0690, -0.2010],
#          [ 1.2621,  2.0117, -0.7737,  ..., -0.2274, -1.0789,  0.6698]]],
#        grad_fn=<NativeLayerNormBackward0>), pooler_output=tensor([[-0.8358,  0.6921,  0.2458, -0.7202, -0.7601,  0.1258, -0.2754, -0.3807,
#           0.6008, -0.1010, -0.0397, -0.2504, -0.3849,  0.5887,  0.0781, -0.1569,
#          -0.7958,  0.6138,  0.3689, -0.1409,  0.6607,  0.5945, -0.8868,  0.6806,
#          -0.5994, -0.0253, -0.6634,  0.3565, -0.1723,  0.0217,  0.4144,  0.0297,
#          -0.5773,  0.4339,  0.1372, -0.7584, -0.1002, -0.0139, -0.1585, -0.4251,
#           0.7798, -0.0275, -0.1843, -0.5360, -0.8222,  0.2375,  0.3551, -0.5215,
#          -0.7428, -0.5048, -0.8381, -0.6749,  0.5992, -0.2061, -0.8676, -0.8087,
# ...
